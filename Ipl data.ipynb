# %% [markdown]
# # Data analysis is where you gather,clean,transform and reduce useful information from an unstructure data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("IPLData.csv")
data
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 0     Shikhar Dhawan     Punjab      Indian      Batter       1
# 1      Shreyas Iyer     Kolkata      Indian      Batter       1
# 2     Faf Du Plessis  Bangalore    Overseas      Batter       1
# 3     Manish Pandey     Lucknow      Indian      Batter       1
# 4    Shimron Hetmyer  Rajasthan    Overseas      Batter       1
# ..               ...        ...         ...         ...     ...
# 230     Ravi Bishnoi    Lucknow      Indian     Bowler        1
# 231  Ruturaj Gaikwad    Chennai      Indian      Batter       1
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 234    Anrich Nortje      Delhi    Overseas     Bowler        1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 0             192.0  5783.0    34.63       126.60      4.0            16.50
# 1              87.0  2375.0    31.67       123.96      NaN              NaN
# 2             100.0  2935.0    34.94       131.09      NaN              NaN
# 3             154.0  3560.0    30.69       121.83      NaN              NaN
# 4              31.0   517.0    25.85       151.17      NaN              NaN
# ..              ...     ...      ...          ...      ...              ...
# 230            23.0     8.0     4.00        50.00     24.0            25.25
# 231            22.0   839.0    46.61       132.13      NaN              NaN
# 232           134.0   954.0    15.64       161.69    143.0            24.53
# 233           178.0  3268.0    29.98       149.77     65.0            31.62
# 234            24.0     7.0     7.00       116.67     34.0            20.56
#
#      Economy  Bowling_Strike_Rate  Catches  Run_outs  Stumps
# 0       8.25                12.00      NaN       NaN     NaN
# 1        NaN                  NaN      NaN       NaN     NaN
# 2        NaN                  NaN      NaN       NaN     NaN
# 3        NaN                  NaN      NaN       NaN     NaN
# 4        NaN                  NaN      NaN       NaN     NaN
# ..       ...                  ...      ...       ...     ...
# 230     6.97                21.75      NaN       NaN     NaN
# 231      NaN                  NaN      NaN       NaN     NaN
# 232     6.74                21.83      NaN       NaN     NaN
# 233     8.78                21.60      NaN       NaN     NaN
# 234     7.65                16.12      NaN       NaN     NaN
#
# [235 rows x 16 columns]

# %%
#first look of the data head() first five row staring
data.head()
# Out:
#        Player Name       Team Nationality Player_Type  Capped  Matches_Played  \
# 0   Shikhar Dhawan     Punjab      Indian      Batter       1           192.0
# 1    Shreyas Iyer     Kolkata      Indian      Batter       1            87.0
# 2   Faf Du Plessis  Bangalore    Overseas      Batter       1           100.0
# 3   Manish Pandey     Lucknow      Indian      Batter       1           154.0
# 4  Shimron Hetmyer  Rajasthan    Overseas      Batter       1            31.0
#
#      Runs  Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 0  5783.0    34.63       126.60      4.0             16.5     8.25
# 1  2375.0    31.67       123.96      NaN              NaN      NaN
# 2  2935.0    34.94       131.09      NaN              NaN      NaN
# 3  3560.0    30.69       121.83      NaN              NaN      NaN
# 4   517.0    25.85       151.17      NaN              NaN      NaN
#
#    Bowling_Strike_Rate  Catches  Run_outs  Stumps
# 0                 12.0      NaN       NaN     NaN
# 1                  NaN      NaN       NaN     NaN
# 2                  NaN      NaN       NaN     NaN
# 3                  NaN      NaN       NaN     NaN
# 4                  NaN      NaN       NaN     NaN

# %%
#describe function will return the neccessary information like,count,mean,std,etc entire dataset
data.describe()
# Out:
#            Capped  Matches_Played         Runs     Average  Strike_Rate  \
# count  235.000000      215.000000   165.000000  161.000000   163.000000
# mean     0.838298       43.897674   840.575758   21.792391   121.009939
# std      0.561802       48.695302  1270.341831   11.664156    30.739189
# min      0.000000        1.000000     0.000000    0.000000     0.000000
# 25%      0.500000       11.500000    67.000000   13.800000   112.635000
# 50%      1.000000       25.000000   289.000000   22.410000   128.630000
# 75%      1.000000       56.000000   954.000000   29.300000   137.550000
# max      2.000000      220.000000  6283.000000   58.500000   190.240000
#
#           Wickets  Bowling_average     Economy  Bowling_Strike_Rate  \
# count  140.000000       135.000000  143.000000           119.000000
# mean    31.485714        32.907185    8.223182            24.686134
# std     36.872420        18.191441    1.223541            12.982049
# min      0.000000         0.000000    5.360000             0.000000
# 25%      6.000000        23.025000    7.390000            18.495000
# 50%     19.500000        29.070000    8.190000            21.750000
# 75%     40.500000        36.030000    8.785000            26.190000
# max    167.000000       153.000000   13.120000           108.000000
#
#           Catches   Run_outs     Stumps
# count   27.000000  27.000000  27.000000
# mean    30.962963   3.444444   6.259259
# std     34.544822   5.010246   9.928950
# min      0.000000   0.000000   0.000000
# 25%      3.500000   0.000000   0.000000
# 50%     19.000000   1.000000   2.000000
# 75%     51.500000   4.000000   7.000000
# max    126.000000  21.000000  39.000000

# %%
#we can check the number of null value using the isna().sum() method
data.isna().sum()
# Out:
# Player Name              0
# Team                     0
# Nationality              0
# Player_Type              0
# Capped                   0
# Matches_Played          20
# Runs                    70
# Average                 74
# Strike_Rate             72
# Wickets                 95
# Bowling_average        100
# Economy                 92
# Bowling_Strike_Rate    116
# Catches                208
# Run_outs               208
# Stumps                 208
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player Name          235 non-null    object
#  1   Team                 235 non-null    object
#  2   Nationality          235 non-null    object
#  3   Player_Type          235 non-null    object
#  4   Capped               235 non-null    int64
#  5   Matches_Played       215 non-null    float64
#  6   Runs                 165 non-null    float64
#  7   Average              161 non-null    float64
#  8   Strike_Rate          163 non-null    float64
#  9   Wickets              140 non-null    float64
#  10  Bowling_average      135 non-null    float64
#  11  Economy              143 non-null    float64
#  12  Bowling_Strike_Rate  119 non-null    float64
#  13  Catches              27 non-null     float64
#  14  Run_outs             27 non-null     float64
#  15  Stumps               27 non-null     float64
# dtypes: float64(11), int64(1), object(4)
# memory usage: 29.5+ KB

# %% [markdown]
# # cleaning data

# %%
in the above the plyers can be intially segragated based on folling parameter
1.Capped Batter,Bowlers,Alround,wicket keeper
2.Uncapped-Batter,Bowler,alround

# %%
batters=data.loc[(data["Player_Type"]=="Batter")]
batters_new=batters.loc[(batters["Capped"]==1)]
Capped_Batters=batters_new[["Player Name","Team","Nationality","Matches_Played","Runs","Average","Strike_Rate"]]

# %%
Capped_Batters.head()
# Out:
#        Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0   Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 1    Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 2   Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 3   Manish Pandey     Lucknow      Indian           154.0  3560.0    30.69
# 4  Shimron Hetmyer  Rajasthan    Overseas            31.0   517.0    25.85
#
#    Strike_Rate
# 0       126.60
# 1       123.96
# 2       131.09
# 3       121.83
# 4       151.17

# %% [markdown]
# # boller

# %%
bowlers=data.loc[(data["Player_Type"]=="Bowler")]
bowlers_new=bowlers.loc[(bowlers["Capped"]==1)]
Capped_Bowlers=bowlers_new[['Player Name',
                            'Team',
                            'Nationality',
                            'Matches_Played',
                            'Wickets',
                            'Bowling_average',
                            'Economy',
                            'Bowling_Strike_Rate'
                           
                           
                           ]]

# %%
print(Capped_Bowlers.head())
# Out:
# Empty DataFrame
# Columns: [Player Name, Team, Nationality, Matches_Played, Wickets, Bowling_average, Economy, Bowling_Strike_Rate]
# Index: []

# %%
Keepers=data.loc[(data["Player_Type"]=="Keeper")]
Keepers_new=Keepers.loc[(Keepers["Capped"]==1)]
Capped_Keepers=Keepers_new[['Player Name',
                           'Nationality',
                            'Matches_Played',
                            'Runs',
                            'Average',
                            'Strike_Rate',
                            'Catches',
                            'Run_outs',
                            'Stumps'
                           
                           
                           ]]

# %%
Capped_Keepers.head()
# Out:
#          Player Name Nationality  Matches_Played    Runs  Average  \
# 105  Quinton De Kock    Overseas            77.0  2256.0     31.3
# 106    Ambati Rayudu      Indian           175.0  3916.0     29.4
# 107     Ishan Kishan      Indian            61.0  1452.0     28.5
# 108   Jonny Bairstow    Overseas            28.0  1038.0     41.5
# 109   Dinesh Karthik      Indian           213.0  4046.0     25.8
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 105        130.9     53.0       0.0    14.0
# 106        127.5     58.0      12.0     2.0
# 107        136.3     19.0       1.0     2.0
# 108        142.2     18.0       1.0     4.0
# 109        129.7    123.0      14.0    32.0

# %% [markdown]
# # Allrounder

# %%
Allrounders=data.loc[(data["Player_Type"]=="Allrounder")]
Allrounders_new=Allrounders.loc[(Allrounders["Capped"]==1)]
Capped_Allrounders=Allrounders_new[['Player Name',
                                    'Team',
                                    'Nationality',
                                    'Runs',
                                    'Average',
                                    'Strike_Rate',
                                    'Wickets',
                                    'Bowling_average',
                                    'Economy',
                                    'Bowling_Strike_Rate'
                                   
                                   
                                   
                                   ]]

# %%
Capped_Allrounders.head()
# Out:
#               Player Name       Team Nationality    Runs  Average  \
# 127  Ravichandran Ashwin   Rajasthan      Indian   456.0    11.12
# 128          Pat Cummins     Kolkata    Overseas   316.0    19.75
# 129         Dwayne Bravo     Chennai    Overseas  1537.0    22.94
# 130          Nitish Rana     Kolkata      Indian  1820.0    28.00
# 131          Jason Holder    Lucknow    Overseas   189.0    14.54
#
#      Strike_Rate  Wickets  Bowling_average  Economy  Bowling_Strike_Rate
# 127       109.88    145.0            27.80     6.91                24.12
# 128       140.44     38.0            30.13     8.24                21.95
# 129       130.25    167.0            24.32     8.36                17.44
# 130       132.46      7.0            22.00     8.03                16.43
# 131       121.15     35.0            22.46     8.20                16.43

# %% [markdown]
# # Cleaning the data by making the null or NAN Value 0

# %%
Capped_Batters=Capped_Batters.fillna(0)
Capped_Bowlers=Capped_Bowlers.fillna(0)
Capped_Allrounders=Capped_Allrounders.fillna(0)
Capped_Keepers=Capped_Keepers.fillna(0)

# %% [markdown]
# # Checking null value in the data

# %%
print(Capped_Bowlers.isna().sum())
print(Capped_Batters.isna().sum())

print(Capped_Allrounders.isna().sum())
print(Capped_Keepers.isna().sum())
# Out:
# Player Name            0.0
# Team                   0.0
# Nationality            0.0
# Matches_Played         0.0
# Wickets                0.0
# Bowling_average        0.0
# Economy                0.0
# Bowling_Strike_Rate    0.0
# dtype: float64
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# dtype: int64
# Player Name            0
# Team                   0
# Nationality            0
# Runs                   0
# Average                0
# Strike_Rate            0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64
# Player Name       0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# Catches           0
# Run_outs          0
# Stumps            0
# dtype: int64

# %% [markdown]
# # Analyzing the Batters Data

# %%
top_batters=Capped_Batters.loc[(Capped_Batters["Average"]>=32.0)]

# %%
#Sorting the data Ascending Orders
top_batters_average=top_batters.sort_values('Average',ascending=False)
top_batters_strike_rate=top_batters.sort_values("Strike_Rate",ascending=False)
top_batters_runs=top_batters.sort_values('Runs',ascending=False)
top_batters_matches=top_batters.sort_values('Matches_Played',ascending=False)

# %%
top_batters_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
#
#      Strike_Rate
# 212       136.38
# 231       132.13
# 19        139.97
# 207       131.27
# 208       129.95
# 2         131.09
# 0         126.60
# 26        136.51

# %%
top_batters_strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
#
#      Strike_Rate
# 19        139.97
# 26        136.51
# 212       136.38
# 231       132.13
# 207       131.27
# 2         131.09
# 208       129.95
# 0         126.60

# %%
top_batters_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 212       136.38
# 2         131.09
# 26        136.51
# 207       131.27
# 231       132.13

# %%
top_batters_matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208      Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0     Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19     David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 2     Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 212        KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 26     David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207  Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 231  Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 19        139.97
# 2         131.09
# 212       136.38
# 26        136.51
# 207       131.27
# 231       132.13

# %%
#Analyszing bowler data
top_bowlers=Capped_Bowlers.loc[(Capped_Bowlers["Bowling_average"]<=24.0)]
top_bowlers_average=top_bowlers.sort_values('Bowling_average')
top_bowlers_strike_rate=top_bowlers.sort_values('Bowling_Strike_Rate')
top_bowlers_wickets=top_bowlers.sort_values('Wickets',ascending=False)
top_bowlers_economy=top_bowlers.sort_values('Economy')
top_bowler_matches=top_bowlers.sort_values("Matches_Played",ascending=False)

# %%
top_bowlers_average
# Out:
# Empty DataFrame
# Columns: [Player Name, Team, Nationality, Matches_Played, Wickets, Bowling_average, Economy, Bowling_Strike_Rate]
# Index: []

# %%
top_bowlers_strike_rate
# Out:
# Empty DataFrame
# Columns: [Player Name, Team, Nationality, Matches_Played, Wickets, Bowling_average, Economy, Bowling_Strike_Rate]
# Index: []

# %%
top_bowler_matches
# Out:
# Empty DataFrame
# Columns: [Player Name, Team, Nationality, Matches_Played, Wickets, Bowling_average, Economy, Bowling_Strike_Rate]
# Index: []

# %%
top_keepers=Capped_Keepers.loc[(Capped_Keepers["Average"]>=25.0)]
top_keepers_average=top_keepers.sort_values('Average',ascending=False)
top_keepers_strike_rate=top_keepers.sort_values('Strike_Rate',ascending=False)
top_keepers_runs=top_keepers.sort_values("Runs",ascending=False)
top_keepers_matches=top_keepers.sort_values('Matches_Played',ascending=False)
top_keepers_catches=top_keepers.sort_values('Catches',ascending=False)
top_keepers_runouts=top_keepers.sort_values('Run_outs',ascending=False)
top_keepers_stumps=top_keepers.sort_values('Stumps',ascending=False)

# %%
top_keepers
# Out:
#          Player Name Nationality  Matches_Played    Runs  Average  \
# 105  Quinton De Kock    Overseas            77.0  2256.0    31.30
# 106    Ambati Rayudu      Indian           175.0  3916.0    29.40
# 107     Ishan Kishan      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow    Overseas            28.0  1038.0    41.50
# 109   Dinesh Karthik      Indian           213.0  4046.0    25.80
# 111        KS Bharat      Indian             8.0   191.0    38.20
# 206    Rishabh Pant       Indian            84.0  2498.0    35.18
# 209     Sanju Samson      Indian           121.0  3068.0    29.22
# 213         MS Dhoni      Indian           220.0  4746.0    39.50
# 219       Jos Butler    Overseas            65.0  1968.0    35.14
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 105       130.90     53.0       0.0    14.0
# 106       127.50     58.0      12.0     2.0
# 107       136.30     19.0       1.0     2.0
# 108       142.20     18.0       1.0     4.0
# 109       129.70    123.0      14.0    32.0
# 111       122.40      4.0       0.0     1.0
# 206       147.46     56.0       5.0    14.0
# 209       134.21     59.0       8.0    10.0
# 213       135.80    126.0      21.0    39.0
# 219       150.00     34.0       3.0     1.0

# %%
top_keepers_average
# Out:
#          Player Name Nationality  Matches_Played    Runs  Average  \
# 108   Jonny Bairstow    Overseas            28.0  1038.0    41.50
# 213         MS Dhoni      Indian           220.0  4746.0    39.50
# 111        KS Bharat      Indian             8.0   191.0    38.20
# 206    Rishabh Pant       Indian            84.0  2498.0    35.18
# 219       Jos Butler    Overseas            65.0  1968.0    35.14
# 105  Quinton De Kock    Overseas            77.0  2256.0    31.30
# 106    Ambati Rayudu      Indian           175.0  3916.0    29.40
# 209     Sanju Samson      Indian           121.0  3068.0    29.22
# 107     Ishan Kishan      Indian            61.0  1452.0    28.50
# 109   Dinesh Karthik      Indian           213.0  4046.0    25.80
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 108       142.20     18.0       1.0     4.0
# 213       135.80    126.0      21.0    39.0
# 111       122.40      4.0       0.0     1.0
# 206       147.46     56.0       5.0    14.0
# 219       150.00     34.0       3.0     1.0
# 105       130.90     53.0       0.0    14.0
# 106       127.50     58.0      12.0     2.0
# 209       134.21     59.0       8.0    10.0
# 107       136.30     19.0       1.0     2.0
# 109       129.70    123.0      14.0    32.0

# %%
top_keepers_strike_rate
# Out:
#          Player Name Nationality  Matches_Played    Runs  Average  \
# 219       Jos Butler    Overseas            65.0  1968.0    35.14
# 206    Rishabh Pant       Indian            84.0  2498.0    35.18
# 108   Jonny Bairstow    Overseas            28.0  1038.0    41.50
# 107     Ishan Kishan      Indian            61.0  1452.0    28.50
# 213         MS Dhoni      Indian           220.0  4746.0    39.50
# 209     Sanju Samson      Indian           121.0  3068.0    29.22
# 105  Quinton De Kock    Overseas            77.0  2256.0    31.30
# 109   Dinesh Karthik      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu      Indian           175.0  3916.0    29.40
# 111        KS Bharat      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 219       150.00     34.0       3.0     1.0
# 206       147.46     56.0       5.0    14.0
# 108       142.20     18.0       1.0     4.0
# 107       136.30     19.0       1.0     2.0
# 213       135.80    126.0      21.0    39.0
# 209       134.21     59.0       8.0    10.0
# 105       130.90     53.0       0.0    14.0
# 109       129.70    123.0      14.0    32.0
# 106       127.50     58.0      12.0     2.0
# 111       122.40      4.0       0.0     1.0

# %%
top_keepers_runs
# Out:
#          Player Name Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu      Indian           175.0  3916.0    29.40
# 209     Sanju Samson      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Overseas            77.0  2256.0    31.30
# 219       Jos Butler    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# 109       129.70    123.0      14.0    32.0
# 106       127.50     58.0      12.0     2.0
# 209       134.21     59.0       8.0    10.0
# 206       147.46     56.0       5.0    14.0
# 105       130.90     53.0       0.0    14.0
# 219       150.00     34.0       3.0     1.0
# 107       136.30     19.0       1.0     2.0
# 108       142.20     18.0       1.0     4.0
# 111       122.40      4.0       0.0     1.0

# %%
top_keepers_matches
# Out:
#          Player Name Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu      Indian           175.0  3916.0    29.40
# 209     Sanju Samson      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Overseas            77.0  2256.0    31.30
# 219       Jos Butler    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# 109       129.70    123.0      14.0    32.0
# 106       127.50     58.0      12.0     2.0
# 209       134.21     59.0       8.0    10.0
# 206       147.46     56.0       5.0    14.0
# 105       130.90     53.0       0.0    14.0
# 219       150.00     34.0       3.0     1.0
# 107       136.30     19.0       1.0     2.0
# 108       142.20     18.0       1.0     4.0
# 111       122.40      4.0       0.0     1.0

# %%
top_keepers_catches
# Out:
#          Player Name Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik      Indian           213.0  4046.0    25.80
# 209     Sanju Samson      Indian           121.0  3068.0    29.22
# 106    Ambati Rayudu      Indian           175.0  3916.0    29.40
# 206    Rishabh Pant       Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Overseas            77.0  2256.0    31.30
# 219       Jos Butler    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# 109       129.70    123.0      14.0    32.0
# 209       134.21     59.0       8.0    10.0
# 106       127.50     58.0      12.0     2.0
# 206       147.46     56.0       5.0    14.0
# 105       130.90     53.0       0.0    14.0
# 219       150.00     34.0       3.0     1.0
# 107       136.30     19.0       1.0     2.0
# 108       142.20     18.0       1.0     4.0
# 111       122.40      4.0       0.0     1.0

# %%
top_keepers_runouts
# Out:
#          Player Name Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu      Indian           175.0  3916.0    29.40
# 209     Sanju Samson      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Indian            84.0  2498.0    35.18
# 219       Jos Butler    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow    Overseas            28.0  1038.0    41.50
# 105  Quinton De Kock    Overseas            77.0  2256.0    31.30
# 111        KS Bharat      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# 109       129.70    123.0      14.0    32.0
# 106       127.50     58.0      12.0     2.0
# 209       134.21     59.0       8.0    10.0
# 206       147.46     56.0       5.0    14.0
# 219       150.00     34.0       3.0     1.0
# 107       136.30     19.0       1.0     2.0
# 108       142.20     18.0       1.0     4.0
# 105       130.90     53.0       0.0    14.0
# 111       122.40      4.0       0.0     1.0

# %%
top_keepers_stumps
# Out:
#          Player Name Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik      Indian           213.0  4046.0    25.80
# 105  Quinton De Kock    Overseas            77.0  2256.0    31.30
# 206    Rishabh Pant       Indian            84.0  2498.0    35.18
# 209     Sanju Samson      Indian           121.0  3068.0    29.22
# 108   Jonny Bairstow    Overseas            28.0  1038.0    41.50
# 106    Ambati Rayudu      Indian           175.0  3916.0    29.40
# 107     Ishan Kishan      Indian            61.0  1452.0    28.50
# 111        KS Bharat      Indian             8.0   191.0    38.20
# 219       Jos Butler    Overseas            65.0  1968.0    35.14
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# 109       129.70    123.0      14.0    32.0
# 105       130.90     53.0       0.0    14.0
# 206       147.46     56.0       5.0    14.0
# 209       134.21     59.0       8.0    10.0
# 108       142.20     18.0       1.0     4.0
# 106       127.50     58.0      12.0     2.0
# 107       136.30     19.0       1.0     2.0
# 111       122.40      4.0       0.0     1.0
# 219       150.00     34.0       3.0     1.0

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Strike_Rate',data=top_batters)
# Out:
# <Axes: xlabel='Player Name', ylabel='Strike_Rate'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Runs',data=top_batters)
# Out:
# <Axes: xlabel='Player Name', ylabel='Runs'>

# %%
sns.barplot(x='Player Name',y='Average',data=top_batters)
# Out:
# <Axes: xlabel='Player Name', ylabel='Average'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Matches_Played',data=top_batters)
# Out:
# <Axes: xlabel='Player Name', ylabel='Matches_Played'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='',data=top_batters)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[117], line 2
#       1 plt.figure(figsize=(20,10))
# ----> 2 sns.barplot(x='Player Name',y='Wicket',data=top_batters)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
#    2761     ax = plt.gca()
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:1530, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1525 def __init__(self, x, y, hue, data, order, hue_order,
#    1526              estimator, errorbar, n_boot, units, seed,
#    1527              orient, color, palette, saturation, width,
#    1528              errcolor, errwidth, capsize, dodge):
#    1529     """Initialize the plotter."""
# -> 1530     self.establish_variables(x, y, hue, data, orient,
#    1531                              order, hue_order, units)
#    1532     self.establish_colors(color, palette, saturation)
#    1533     self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:541, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539     if isinstance(var, str):
#     540         err = f"Could not interpret input '{var}'"
# --> 541         raise ValueError(err)
#     543 # Figure out the plotting orientation
#     544 orient = infer_orient(
#     545     x, y, orient, require_numeric=self.require_numeric
#     546 )
#
# ValueError: Could not interpret input 'Wicket'

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Average',data=top_keepers)
# Out:
# <Axes: xlabel='Player Name', ylabel='Average'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Runs',data=top_keepers)
# Out:
# <Axes: xlabel='Player Name', ylabel='Runs'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Strike_Rate',data=top_keepers)
# Out:
# <Axes: xlabel='Player Name', ylabel='Strike_Rate'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Catches',data=top_keepers)
# Out:
# <Axes: xlabel='Player Name', ylabel='Catches'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Run_outs',data=top_keepers)
# Out:
# <Axes: xlabel='Player Name', ylabel='Run_outs'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name',y='Matches_Played',data=top_keepers)
# Out:
# <Axes: xlabel='Player Name', ylabel='Matches_Played'>

# %%
data
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 0     Shikhar Dhawan     Punjab      Indian      Batter       1
# 1      Shreyas Iyer     Kolkata      Indian      Batter       1
# 2     Faf Du Plessis  Bangalore    Overseas      Batter       1
# 3     Manish Pandey     Lucknow      Indian      Batter       1
# 4    Shimron Hetmyer  Rajasthan    Overseas      Batter       1
# ..               ...        ...         ...         ...     ...
# 230     Ravi Bishnoi    Lucknow      Indian     Bowler        1
# 231  Ruturaj Gaikwad    Chennai      Indian      Batter       1
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 234    Anrich Nortje      Delhi    Overseas     Bowler        1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 0             192.0  5783.0    34.63       126.60      4.0            16.50
# 1              87.0  2375.0    31.67       123.96      NaN              NaN
# 2             100.0  2935.0    34.94       131.09      NaN              NaN
# 3             154.0  3560.0    30.69       121.83      NaN              NaN
# 4              31.0   517.0    25.85       151.17      NaN              NaN
# ..              ...     ...      ...          ...      ...              ...
# 230            23.0     8.0     4.00        50.00     24.0            25.25
# 231            22.0   839.0    46.61       132.13      NaN              NaN
# 232           134.0   954.0    15.64       161.69    143.0            24.53
# 233           178.0  3268.0    29.98       149.77     65.0            31.62
# 234            24.0     7.0     7.00       116.67     34.0            20.56
#
#      Economy  Bowling_Strike_Rate  Catches  Run_outs  Stumps
# 0       8.25                12.00      NaN       NaN     NaN
# 1        NaN                  NaN      NaN       NaN     NaN
# 2        NaN                  NaN      NaN       NaN     NaN
# 3        NaN                  NaN      NaN       NaN     NaN
# 4        NaN                  NaN      NaN       NaN     NaN
# ..       ...                  ...      ...       ...     ...
# 230     6.97                21.75      NaN       NaN     NaN
# 231      NaN                  NaN      NaN       NaN     NaN
# 232     6.74                21.83      NaN       NaN     NaN
# 233     8.78                21.60      NaN       NaN     NaN
# 234     7.65                16.12      NaN       NaN     NaN
#
# [235 rows x 16 columns]

# %%
data.ndim
# Out:
# 2

# %%
data.shape
# Out:
# (235, 16)

# %%
data.size
# Out:
# 3760
